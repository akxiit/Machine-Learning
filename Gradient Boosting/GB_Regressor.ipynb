# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df_copy = df.copy()

# %%
df_copy['children'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
x = df_copy.drop('charges', axis=1)
y = df_copy['charges']

# %%
ohe_cat = ['sex', 'children', 'region']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train['smoker']= x_train['smoker'].map({'yes': 1, 'no': 0})
x_test['smoker']= x_test['smoker'].map({'yes': 1, 'no': 0})

# %%
col_transformer = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(drop='first'), ohe_cat)
    ],
    remainder='passthrough'
)

# %%
x_train_en = col_transformer.fit_transform(x_train)
x_test_en = col_transformer.transform(x_test)

# %%
x_train_en
# Out:
# array([[ 0.   ,  0.   ,  1.   , ..., 46.   , 19.95 ,  0.   ],
#        [ 0.   ,  0.   ,  0.   , ..., 47.   , 24.32 ,  0.   ],
#        [ 0.   ,  0.   ,  0.   , ..., 52.   , 24.86 ,  0.   ],
#        ...,
#        [ 1.   ,  0.   ,  0.   , ..., 58.   , 25.175,  0.   ],
#        [ 0.   ,  0.   ,  1.   , ..., 37.   , 47.6  ,  1.   ],
#        [ 1.   ,  0.   ,  0.   , ..., 55.   , 29.9  ,  0.   ]])

# %%
x_train_en.shape
# Out:
# (1070, 12)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train_en, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test_en)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'R2: {r2}')
# Out:
# MAE: 4214.909953083622
# MSE: 33756429.70235279
# R2: 0.7825655038982298

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100)
rf.fit(x_train_en, y_train)



y_pred_rf = rf.predict(x_test_en)
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)


print(f'Random Forest MAE: {mae_rf}')
print(f'Random Forest MSE: {mse_rf}')
print(f'Random Forest R2: {r2_rf}')
# Out:
# Random Forest MAE: 2475.695017530847
# Random Forest MSE: 20867042.15277032
# Random Forest R2: 0.8655896125381478

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(x_train_en, y_train)

# %%
y_pred_gbr = gbr.predict(x_test_en)
mae_gbr = mean_absolute_error(y_test, y_pred_gbr)
mse_gbr = mean_squared_error(y_test, y_pred_gbr)
r2_gbr = r2_score(y_test, y_pred_gbr)

# %%
print(f'GBR MAE: {mae_gbr}')
print(f'GBR MSE: {mse_gbr}')
print(f'GBR R2: {r2_gbr}')
# Out:
# GBR MAE: 2447.8611470602327
# GBR MSE: 19010752.503366254
# GBR R2: 0.877546487364545
