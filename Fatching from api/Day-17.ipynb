# %%
import requests

url = "https://instagram-scraper-api2.p.rapidapi.com/v1/posts"

querystring = {"username_or_id_or_url":"mrbeast"}

headers = {
	"x-rapidapi-key": "1f214c7b3dmsh89c608ba93c55eep12ecc2jsn605b4fd06a92",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
# Out:
# {'data': {'count': 12, 'items': [{'boost_unavailable_identifier': None, 'boost_unavailable_reason': None, 'boost_unavailable_reason_v2': None, 'can_modify_carousel': False, 'can_reply': False, 'can_reshare': True, 'can_save': True, 'caption': {'created_at': 1732824650, 'created_at_utc': 1732824650, 'did_report_as_spam': False, 'hashtags': [], 'id': '3511510130787749851', 'is_covered': False, 'is_ranked_comment': False, 'mentions': [], 'private_reply_status': 0, 'share_enabled': False, 'text': 'We are both dropping big videos together November 30th 👀', 'text_translation': 'We are both dropping big videos together November 30th 👀', 'type': 1, 'user': {'fbid_v2': 17841402202464771, 'full_name': 'MrBeast', 'id': '2278169415', 'is_private': False, 'is_unpublished': False, 'is_verified': True, 'profile_pic_id': '1765328607101572916', 'profile_pic_url': 'https://scontent-muc2-1.cdninstagram.com/v/t51.2885-19/31077884_211593632905749_1394765701385814016_n.jpg?stp=dst-jpg_e0_s150x150_tt6&_nc_
# ...

# %%
import pandas as pd

# Extract the 'items' list from the response data
items = response.json()['data']['items']

# Convert the 'items' list to a DataFrame
df = pd.DataFrame(items)[['id','comment_count', 'like_count']]
df
# Out:
#                      id  comment_count  like_count
# 0   3511510130787749851         100939    17942047
# 1   3362814775367218923       10198742    15722657
# 2   3563598675282558742           7953     1847584
# 3   3562064314388176564           6765     1603050
# 4   3555633225185826983           6024      569706
# 5   3551985836457182348          12035     2468964
# 6   3546213250692017654          33676     1609528
# 7   3544753404805226974          17424     3874954
# 8   3543304611136253564          48148     7385279
# 9   3541772078338668440           7483     2025739
# 10  3536892104284890859          80768     7800616
# 11  3536065721631375397          80390     8977611
