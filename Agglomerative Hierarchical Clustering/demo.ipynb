# %%
! pip install pycaret
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pycaret
#   Using cached pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pycaret) (8.29.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pycaret) (4.67.1)
# Collecting numpy<1.27,>=1.21 (from pycaret)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
#       + C:\Program Files\Python313\python.exe D:\Temp\pip-install-0rf6yu42\numpy_04706a7237eb4a14aab968e6a2580fba\vendored-meson\meson\meson.py setup D:\Temp\pip-install-0rf6yu42\numpy_04706a7237eb4a14aab968e6a2580fba D:\Temp\pip-install-0rf6yu42\numpy_04706a7237eb4a14aab968e6a2580fba\.mesonpy-ee7phgtz -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=D:\Temp\pip-install-0rf6yu42\numpy_04706a7237eb4a14aab968e6a2580fba\.mesonpy-ee7phgtz\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: D:\Temp\pip-install-0rf6yu42\numpy_04706a7237eb4a14aab968e6a2580fba
#       Build dir: D:\Temp\pip-install-0rf6yu42\numpy_04706a7237eb4a14aab968e6a2580fba\.mesonpy-ee7phgtz
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       C compiler for the host machine: gcc (gcc 6.3.0 "gcc (MinGW.org GCC-6.3.0-1) 6.3.0")
#       C linker for the host machine: gcc ld.bfd 2.28
#       C++ compiler for the host machine: c++ (gcc 6.3.0 "c++ (MinGW.org GCC-6.3.0-1) 6.3.0")
#       C++ linker for the host machine: c++ ld.bfd 2.28
#       Cython compiler for the host machine: cython (cython 3.0.12)
#       Host machine cpu family: x86
#       Host machine cpu: x86
#
#       ..\meson.build:28:4: ERROR: Problem encountered: NumPy requires GCC >= 8.4
#
#       A full log can be found at D:\Temp\pip-install-0rf6yu42\numpy_04706a7237eb4a14aab968e6a2580fba\.mesonpy-ee7phgtz\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Program Files\Python313\python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
! pip install pandas matplotlib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\admin\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\roaming\python\python313\site-packages (3.10.0)
# Requirement already satisfied: scikit-learn in c:\users\admin\appdata\roaming\python\python313\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\roaming\python\python313\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\admin\appdata\roaming\python\python313\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: C:\Program Files\Python313\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data = df.iloc[: , 3:5].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = df.iloc[: , 3:5].values
#
# NameError: name 'df' is not defined

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import scipy.cluster.hierarchy as sch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import scipy.cluster.hierarchy as sch
#
# ModuleNotFoundError: No module named 'scipy'

# %%
plt.figure(figsize=(10, 7))
dend = sch.dendrogram(sch.linkage(data, method='ward'))
threshold = 200  
plt.axhline(y=threshold, color='red', linestyle='--')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.figure(figsize=(10, 7))
#       2 dend = sch.dendrogram(sch.linkage(data, method='ward'))
#       3 threshold = 200
#
# NameError: name 'plt' is not defined

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=5, metric='euclidean', linkage='ward')
labels_ = cluster.fit_predict(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sklearn.cluster import AgglomerativeClustering
#       3 cluster = AgglomerativeClustering(n_clusters=5, metric='euclidean', linkage='ward')
#       4 labels_ = cluster.fit_predict(data)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 labels_
#
# NameError: name 'labels_' is not defined

# %%
plt.figure(figsize=(10, 7))
plt.scatter(data[:, 0], data[:, 1], c=labels_, cmap='rainbow')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.figure(figsize=(10, 7))
#       2 plt.scatter(data[:, 0], data[:, 1], c=labels_, cmap='rainbow')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import pycaret
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import pycaret
#
# ModuleNotFoundError: No module named 'pycaret'
